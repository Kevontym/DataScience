# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevontym/DataScience/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science Tools and Ecosystem
#
# [2-title.png](data:image/png;base64,...)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# **Objectives:**
#
#
# *   When learning about data science i learned about the different environments such as Rstudio and Google Colab!
# *   You should defintely familiarize yourself with the libraries because \
# you aren going to use them
# *   Be CURIOUS!!!! Thats what really keeps you going as a data scientist!![10-objectives.png](data:image/png;base64,...)
#
#
#
#
# \
# [3-intro.png](data:image/png;base64,...)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Julia \
# [4-dslanguages.png](data:image/png;base64,...)

# %% [markdown]
# | Data Science Tools |
# | -----|
# | Jypter Notebooks |
# | R Studio |
# | VIsual Studio Code | \![Screenshot 2024-03-10 at 7.45.51 PM.png](data:image/png;base64,...)
#
# [5-dslibraries.png](data:image/png;base64,...)

# %% [markdown]
# 1. Matplotlib
# 2. Seaborn
# 3. Pandas \
# [ds-tools.png](data:image/png;base64,...)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# ![7-introarithmatic.png](data:image/png;base64,...)

# %% [markdown]
# (3*4)+5
# [8-multiplyandaddntegers.png](data:image/png;base64,...)

# %% [markdown]
# def conversion():
#   i = 200 // 60
#   return i
#
# result = conversion
# print(result)
#
# [9-hourstominutes.png](data:image/png;base64,...)

# %% [markdown]
# ## Author
# Kevon M. \
#
# [11-authordetails](data:image/png;base64,...)
